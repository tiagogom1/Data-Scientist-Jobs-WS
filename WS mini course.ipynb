# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
response = requests.get(url)

soup = BeautifulSoup(response.text, features="html.parser")
a_s = soup.find_all("a", attrs={"class":"external text"})

tickers = []

for a in a_s:
    if a.text!="reports":
        if len(a.text)>5:
            break
        else:
            tickers.append(a.text)

sp500 = {}

for ticker in tickers:
    url = "https://finance.yahoo.com/quote/"+ticker+"?p="+ticker+"&.tsrc=fin-srch"
    response = requests.get(url)

    soup = BeautifulSoup(response.text, features="html.parser")
    trs = soup.find_all("tr")

    namVal = {}

    for tr in trs:
        namVal[tr.contents[0].text]=tr.contents[1].text
        if(tr.contents[0].text=="1y Target Est"):
            break    

    sp500[ticker]=namVal
# Out:
# MMM
# AOS
# ABT
# ABBV
# ABMD
# ACN
# ATVI
# ADM
# ADBE
# ADP
# AAP
# AES
# AFL
# A
# AIG
# APD
# AKAM
# ALK
# ALB
# ARE
# ALGN
# ALLE
# LNT
# ALL
# GOOGL
# GOOG
# MO
# AMZN
# AMCR
# AMD
# AEE
# AAL
# AEP
# AXP
# AMT
# AWK
# AMP
# ABC
# AME
# AMGN
# APH
# ADI
# ANSS
# ANTM
# AON
# APA
# AAPL
# AMAT
# APTV
# ANET
# AIZ
# T
# ATO
# ADSK
# AZO
# AVB
# AVY
# BKR
# BLL
# BAC
# BBWI
# BAX
# BDX
# WRB
# BRK.B
# BBY
# BIO
# TECH
# BIIB
# BLK
# BK
# BA
# BKNG
# BWA
# BXP
# BSX
# BMY
# AVGO
# BR
# BRO
# BF.B
# CHRW
# CDNS
# CZR
# CPT
# CPB
# COF
# CAH
# KMX
# CCL
# CARR
# CTLT
# CAT
# CBOE
# CBRE
# CDW
# CE
# CNC
# CNP
# CDAY
# CERN
# CF
# CRL
# SCHW
# CHTR
# CVX
# CMG
# CB
# CHD
# CI
# CINF
# CTAS
# CSCO
# C
# CFG
# CTXS
# CLX
# CME
# CMS
# KO
# CTSH
# CL
# CMCSA
# CMA
# CAG
# COP
# ED
# STZ
# CEG
# COO
# CPRT
# GLW
# CTVA
# COST
# CTRA
# CCI
# CSX
# CMI
# CVS
# DHI
# DHR
# DRI
# DVA
# DE
# DAL
# XRAY
# DVN
# DXCM
# FANG
# DLR
# DFS
# DISH
# DIS
# DG
# DLTR
# D
# DPZ
# DOV
# DOW
# DTE
# DUK
# ...

# %%
sp500
# Out:
# {'MMM': {'Previous Close': '144.21',
#   'Open': '144.75',
#   'Bid': '145.00 x 900',
#   'Ask': '146.80 x 800',
#   "Day's Range": '144.12 - 147.73',
#   '52 Week Range': '139.74 - 208.95',
#   'Volume': '2,489,193',
#   'Avg. Volume': '3,446,638',
#   'Market Cap': '83.748B',
#   'Beta (5Y Monthly)': '0.97',
#   'PE Ratio (TTM)': '14.54',
#   'EPS (TTM)': '10.12',
#   'Earnings Date': 'Jul 25, 2022 - Jul 29, 2022',
#   'Forward Dividend & Yield': '5.96 (4.13%)',
#   'Ex-Dividend Date': 'Feb 17, 2022',
#   '1y Target Est': '160.62'},
#  'AOS': {'Previous Close': '59.87',
#   'Open': '59.74',
#   'Bid': '58.67 x 1300',
#   'Ask': '58.69 x 800',
#   "Day's Range": '58.35 - 60.38',
#   '52 Week Range': '58.35 - 86.74',
#   'Volume': '952,025',
#   'Avg. Volume': '1,118,954',
#   'Market Cap': '9.202B',
#   'Beta (5Y Monthly)': '1.17',
#   'PE Ratio (TTM)': '19.40',
#   'EPS (TTM)': '3.02',
#   'Earnings Date': 'Jul 27, 2022 - Aug 01, 2022',
# ...

# %%
url = "https://finance.yahoo.com/chart/AAPL#...-"
response = requests.get(url)

# %%
driver = webdriver.Chrome(executable_path="chromedriver.exe")
driver.get(url)
ps = driver.page_source
driver.close()
# Out:
# C:\Users\Santiago Gómez\AppData\Local\Temp\ipykernel_26784\3718666884.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="chromedriver.exe")
# <bound method WebDriver.close of <selenium.webdriver.chrome.webdriver.WebDriver (session="263740c2d91f1f89508159dcaf365ee9")>>

# %%
driver = webdriver.Chrome(executable_path="chromedriver.exe")
driver.get(url)
xPath = '//*[@id="data-util-col"]/section[2]/table/tbody/tr[1]'
driver.implicitly_wait(20)
elem = driver.find_elements(by=By.XPATH, value=xPath)
print(elem[0].text)
driver.close()
# Out:
# C:\Users\Santiago Gómez\AppData\Local\Temp\ipykernel_26784\3377370028.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="chromedriver.exe")
